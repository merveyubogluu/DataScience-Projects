# %% [markdown]
# # Veri Setine İlk Bakış

# %%
#İhtiyacımız olan kütüphaneleri en başta import ediyoruz.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips = sns.load_dataset("tips")
df = tips.copy()
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
#describe() komutunun sonuna koyduğumuz T transpose almak oluyor. Daha iyi incelemenizi sağlar.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
df.shape
# Out:
# (244, 7)

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %% [markdown]
# # Veri Görselleştirmeye İlk Adım

# %%
#Scatterplot

# %%
sns.scatterplot(x= "total_bill",y= "tip",data= df)

# %%
sns.scatterplot(x= "total_bill",y= "tip",data= df, hue="sex")

# %%
#Catplot

# %%
sns.catplot(x= "sex", y="tip",data=df)

# %%
#Barplot

# %%
sns.barplot(x= "sex", y="tip",data=df)

# %%
df["sex"].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df.groupby(["sex"])["tip"].mean()
# Out:
# sex
# Male      3.089618
# Female    2.833448
# Name: tip, dtype: float64

# %%
sns.scatterplot(x="total_bill",y="tip",hue="sex",style="smoker",data=df)

# %%
sns.scatterplot(x="total_bill",y="tip",hue="smoker",data=df)

# %%
sns.catplot(x="smoker" ,y="tip",data=df)

# %%
df.groupby(["smoker"])["tip"].mean()
# Out:
# smoker
# Yes    3.008710
# No     2.991854
# Name: tip, dtype: float64

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(y="total_bill",x="tip",data=df,size="size", hue="sex")

# %%
sns.catplot(x="time",y="tip",data=df)

# %%
sns.catplot(x="time",y="tip",data=df,hue="day")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df["day"].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
df["time"].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
uniqueDay= df["day"].unique()

# %%
uniqueDay
# Out:
# [Sun, Sat, Thur, Fri]
# Categories (4, object): [Sun, Sat, Thur, Fri]

# %%
sns.barplot(y="tip",x="day",data=df)

# %%
sns.barplot(x="day",y="tip",data=df, hue= "time",color="pink")

# %%
sns.barplot(x="day",y="total_bill",data=df, hue= "time",color="purple")

# %%
sns.barplot(x="sex",y="tip",data=df,hue="smoker")

# %%
sns.lmplot(x="total_bill",y="tip",data=df,col="time",row="sex",hue="smoker")

# %%
sns.pairplot(df,hue="sex")

# %%
sns.lineplot(x= "sex",y= "tip",data=df)
